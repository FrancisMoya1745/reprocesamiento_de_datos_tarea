# %% [markdown]
# <a href="https://colab.research.google.com/github/FrancisMoya1745/reprocesamiento_de_datos_tarea/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/1.1.6. Archivo para actividad práctica.csv')

# %%
df.describe()
# Out:
#              S.NO  Current Rank         Year  earnings ($ million)
# count  301.000000    301.000000   301.000000            301.000000
# mean   151.000000      5.448505  2005.122924             45.516279
# std     87.035433      2.850995     9.063563             33.525337
# min      1.000000      1.000000  1990.000000              8.100000
# 25%     76.000000      3.000000  1997.000000             24.000000
# 50%    151.000000      5.000000  2005.000000             39.000000
# 75%    226.000000      8.000000  2013.000000             59.400000
# max    301.000000     10.000000  2020.000000            300.000000

# %% [markdown]
# S.NO
# Cuantitativa
# Discreta (Identificador)
# Es un número entero que identifica cada registro. No tiene significado analítico.

# %% [markdown]
# Current Rank
# Cuantitativa
# Discreta
# Representa una posición en un ranking (1,2,3...).

# %% [markdown]
# Year
# Cuantitativa
# Discreta
# Representa años enteros.

# %% [markdown]
# earnings ($ million)
# Cuantitativa
# Continua
# Representa dinero y puede tener valores decimales.
